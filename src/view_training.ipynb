# %% [markdown]
# # Explore Training Curves
#
# A basic notebook to generate plots from training logs. See **`Logger`** class in **`utils.py`**.
#
# Python Notebook by Patrick Coady: [Learning Artificial Intelligence](https://learningai.io/)

# %% [markdown]
# ## Summary
#
# Hypothesis, conditions, and results explored in this notebook ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
plt.rcParams["figure.figsize"] = (10,5)
plt.style.use('ggplot')

# %%
def df_plot(dfs, x, ys, ylim=None, legend_loc='best'):
    """ Plot y vs. x curves from pandas dataframe(s)
    
    Args:
        dfs: list of pandas dataframes
        x: str column label for x variable
        y: list of str column labels for y variable(s)
        ylim: tuple to override automatic y-axis limits
        legend_loc: str to override automatic legend placement:
            'upper left', 'lower left', 'lower right' , 'right' ,
            'center left', 'center right', 'lower center',
            'upper center', and 'center'
    """
    if ylim is not None:
        plt.ylim(ylim)
    for df, name in dfs:
        print(name)
        # name = name.split('_')[1]
        for y in ys:
            plt.plot(df[x], df[y], linewidth=2,
                     label=name + ' ' + y.replace('_', ' '))
    plt.xlabel(x.replace('_', ''))
    plt.legend(loc=legend_loc)
    plt.show()

# %%
# ENTER LIST OF LOG FILENAMES HERE:
filepaths = ['src/log-files/Humanoid-v2/Feb-26_02.01.28/log.csv',
             'src/log-files/Humanoid-v2/Baseline/log.csv',
             'src/log-files/Humanoid-v2/BatchNorm/log.csv',
             'src/log-files/Humanoid-v2/BatchNorm_Scale/log.csv']
dataframes = []
names = []
for filepath in filepaths:
    names.append(filepath.split('/')[3])
    dataframes.append(pd.read_csv(filepath))
data = list(zip(dataframes, names))

# %% [markdown]
# # Plots

# %%
df_plot(data, '_Episode', ['_MeanReward'])
df_plot(data, '_Episode', ['KL'])
df_plot(data, '_Episode', ['ExplainedVarOld'])
df_plot(data, '_Episode', ['PolicyLoss'], ylim=(-0.05, 0))
# Out:
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm_Scale
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm_Scale
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm_Scale
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm_Scale

# %%
df_plot(data, '_Episode', ['_mean_discrew'])
df_plot(data, '_Episode', ['_std_discrew'])
df_plot(data, '_Episode', ['_mean_adv'])
df_plot(data, '_Episode', ['_std_adv'])
# Out:
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm_Scale
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm_Scale
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm_Scale
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm_Scale

# %%
df_plot(data, '_Episode', ['_mean_obs'])
df_plot(data, '_Episode', ['_min_obs'])
df_plot(data, '_Episode', ['_max_obs'])
# Out:
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm2
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm2
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm2

# %%
df_plot(data, '_Episode', ['_mean_act'])
df_plot(data, '_Episode', ['_min_act'])
df_plot(data, '_Episode', ['_max_act'])
df_plot(data, '_Episode', ['_std_act'])
# Out:
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm2
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm2
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm2
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm2

# %%
df_plot(data, '_Episode', ['PolicyEntropy'])
# Out:
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_Episode'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-129-4832143515e0> in <module>()
# ----> 1 df_plot(data, '_Episode', ['PolicyEntropy'])
#
# <ipython-input-121-68b5262a2a65> in df_plot(dfs, x, ys, ylim, legend_loc)
#      18         # name = name.split('_')[1]
#      19         for y in ys:
# ---> 20             plt.plot(df[x], df[y], linewidth=2,
#      21                      label=name + ' ' + y.replace('_', ' '))
#      22     plt.xlabel(x.replace('_', ''))
#
# C:\Python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\Python36\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\Python36\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# C:\Python36\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\Python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_Episode'

# %%
df_plot(data, '_Episode', ['_lr_multiplier'])
# Out:
# Feb-26_02.01.28
# Baseline
# BatchNorm
# BatchNorm2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_Episode'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-aa663f220004> in <module>()
# ----> 1 df_plot(data, '_Episode', ['_lr_multiplier'])
#
# <ipython-input-121-68b5262a2a65> in df_plot(dfs, x, ys, ylim, legend_loc)
#      18         # name = name.split('_')[1]
#      19         for y in ys:
# ---> 20             plt.plot(df[x], df[y], linewidth=2,
#      21                      label=name + ' ' + y.replace('_', ' '))
#      22     plt.xlabel(x.replace('_', ''))
#
# C:\Python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# C:\Python36\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# C:\Python36\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# C:\Python36\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# C:\Python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_Episode'
